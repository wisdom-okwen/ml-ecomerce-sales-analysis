# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv('data/ecommerce_sales_analysis.csv')

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.shape
# Out:
# (1000, 18)

# %%
df.describe()
# Out:
#         product_id        price  review_score  review_count  sales_month_1  \
# count  1000.000000  1000.000000   1000.000000   1000.000000    1000.000000
# mean    500.500000   247.677130      3.027600    526.506000     498.306000
# std     288.819436   144.607983      1.171243    282.269932     289.941478
# min       1.000000     7.290000      1.000000      1.000000       0.000000
# 25%     250.750000   121.810000      2.000000    283.750000     245.500000
# 50%     500.500000   250.920000      3.100000    543.000000     507.500000
# 75%     750.250000   373.435000      4.000000    772.000000     740.750000
# max    1000.000000   499.860000      5.000000    999.000000    1000.000000
#
#        sales_month_2  sales_month_3  sales_month_4  sales_month_5  \
# count    1000.000000    1000.000000    1000.000000    1000.000000
# mean      507.661000     506.739000     503.823000     487.194000
# std       285.992689     294.010873     286.645567     287.844324
# ...

# %%
df.head()
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
# 3           951            725            678             59             15
# 4           220            682            451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# ...

# %%
month1_sales_by_cat = df.groupby(['category'])['sales_month_1'].mean()
month1_sales_by_cat
# Out:
# category
# Books             506.051948
# Clothing          435.471429
# Electronics       553.239130
# Health            486.647482
# Home & Kitchen    462.752000
# Sports            508.084967
# Toys              528.715232
# Name: sales_month_1, dtype: float64

# %%
month2_sales_by_cat = df.groupby(['category'])['sales_month_2'].mean()
month2_sales_by_cat
# Out:
# category
# Books             519.993506
# Clothing          485.078571
# Electronics       525.159420
# Health            485.122302
# Home & Kitchen    458.016000
# Sports            537.542484
# Toys              531.596026
# Name: sales_month_2, dtype: float64

# %%
month3_sales_by_cat = df.groupby(['category'])['sales_month_3'].mean()
month3_sales_by_cat
# Out:
# category
# Books             499.987013
# Clothing          548.542857
# Electronics       512.376812
# Health            486.345324
# Home & Kitchen    501.336000
# Sports            490.908497
# Toys              509.000000
# Name: sales_month_3, dtype: float64

# %%
df['sales_month_1']
# Out:
# 0      479
# 1       21
# 2      348
# 3      725
# 4      682
#       ...
# 995    488
# 996     18
# 997    725
# 998    196
# 999    890
# Name: sales_month_1, Length: 1000, dtype: int64

# %%
df['average_sales'] = df[
    ['sales_month_1', 
    'sales_month_2', 
    'sales_month_3', 
    'sales_month_4', 
    'sales_month_5', 
    'sales_month_6',
    'sales_month_7', 
    'sales_month_8', 
    'sales_month_9', 
    'sales_month_10', 
    'sales_month_11', 
    'sales_month_12'
]].mean(axis=1)

# %%
df.head()
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
# 3           951            725            678             59             15
# 4           220            682            451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# ...
